# %% [markdown]
# # Drug Poisoning Data Analysis
#
# Import libraries

# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Load in data

# %%
df = pd.read_csv("data.csv")
df.shape
# Out:
# (2703, 18)

# %%
df
# Out:
#       Year         Sex                 Age Race and Hispanic Origin  \
# 0     2014  Both Sexes         15-24 years    All Races-All Origins
# 1     2012        Male         15-24 years       Non-Hispanic White
# 2     2008        Male  Less than 15 years       Non-Hispanic Black
# 3     2003  Both Sexes         35-44 years       Non-Hispanic White
# 4     2010      Female  Less than 15 years       Non-Hispanic White
# 5     2001  Both Sexes         45-54 years       Non-Hispanic White
# 6     2003        Male  Less than 15 years       Non-Hispanic White
# 7     2010  Both Sexes         15-24 years       Non-Hispanic White
# 8     2011  Both Sexes           75+ years                 Hispanic
# 9     2001        Male         55-64 years       Non-Hispanic Black
# 10    2002      Female  Less than 15 years       Non-Hispanic White
# 11    2004      Female         15-24 years       Non-Hispanic Black
# 12    2011  Both Sexes         65-74 years    All Races-All Origins
# 13    2000  Both Sexes  Less than 15 years       Non-Hispanic Black
# 14    2005      Female         55-64 years       Non-Hispanic White
# 15    2001  Both Sexes           75+ years       Non-Hispanic White
# 16    2009  Both Sexes         45-54 years    All Races-All Origins
# 17    1999        Male         55-64 years       Non-Hispanic White
# 18    2015        Male           75+ years       Non-Hispanic White
# 19    2011        Male         65-74 years                 Hispanic
# 20    2003        Male         35-44 years       Non-Hispanic Black
# 21    1999  Both Sexes         65-74 years       Non-Hispanic Black
# 22    1999      Female         55-64 years    All Races-All Origins
# 23    2014      Female  Less than 15 years       Non-Hispanic White
# 24    2014  Both Sexes           75+ years       Non-Hispanic Black
# 25    2008      Female         15-24 years       Non-Hispanic White
# 26    2006      Female         15-24 years                 Hispanic
# 27    2015        Male         45-54 years       Non-Hispanic Black
# 28    2006        Male         35-44 years       Non-Hispanic Black
# 29    2013        Male           75+ years    All Races-All Origins
# ...    ...         ...                 ...                      ...
# 2673  2004        Male            All Ages       Non-Hispanic Black
# 2674  2010  Both Sexes            All Ages    All Races-All Origins
# 2675  2008  Both Sexes            All Ages    All Races-All Origins
# 2676  2002  Both Sexes            All Ages    All Races-All Origins
# 2677  2002  Both Sexes            All Ages    All Races-All Origins
# 2678  2005      Female            All Ages       Non-Hispanic White
# 2679  2000  Both Sexes            All Ages    All Races-All Origins
# 2680  2010  Both Sexes            All Ages    All Races-All Origins
# 2681  2000  Both Sexes            All Ages    All Races-All Origins
# 2682  2006  Both Sexes            All Ages    All Races-All Origins
# 2683  2002  Both Sexes            All Ages    All Races-All Origins
# 2684  2011  Both Sexes            All Ages       Non-Hispanic Black
# 2685  2011  Both Sexes            All Ages    All Races-All Origins
# 2686  2011  Both Sexes            All Ages    All Races-All Origins
# 2687  2009  Both Sexes            All Ages    All Races-All Origins
# 2688  2000  Both Sexes            All Ages    All Races-All Origins
# 2689  2000  Both Sexes            All Ages    All Races-All Origins
# 2690  2014  Both Sexes            All Ages       Non-Hispanic Black
# 2691  2008  Both Sexes            All Ages    All Races-All Origins
# 2692  2000  Both Sexes            All Ages       Non-Hispanic White
# 2693  2015  Both Sexes            All Ages    All Races-All Origins
# 2694  2013  Both Sexes            All Ages    All Races-All Origins
# 2695  2002  Both Sexes            All Ages    All Races-All Origins
# 2696  2008  Both Sexes            All Ages    All Races-All Origins
# 2697  2006  Both Sexes            All Ages    All Races-All Origins
# 2698  2011  Both Sexes            All Ages    All Races-All Origins
# 2699  2002  Both Sexes            All Ages    All Races-All Origins
# 2700  2007  Both Sexes            All Ages    All Races-All Origins
# 2701  2013  Both Sexes            All Ages    All Races-All Origins
# 2702  2005  Both Sexes            All Ages    All Races-All Origins
#
#                      State  Deaths  Population  Crude Death Rate  \
# 0            United States    3798    43979821               8.6
# 1            United States    2137    12857283              16.6
# 2            United States      15     4687984               0.3
# 3            United States    6533    30270056              21.6
# 4            United States      28    16460571               0.2
# 5            United States    3850    29733531              12.9
# 6            United States      38    18562010               0.2
# 7            United States    3020    25356574              11.9
# 8            United States      21     1213487               1.7
# 9            United States     129     1100021              11.7
# 10           United States      24    17779985               0.1
# 11           United States      38     3065345               1.2
# 12           United States    1204    22481738               5.4
# 13           United States      14     9411199               0.1
# 14           United States    1031    12166744               8.5
# 15           United States     418    14549012               2.9
# 16           United States   11390    44867088              25.4
# 17           United States     370     9153776               4.0
# 18           United States     291     6618453               4.4
# 19           United States      26      786108               3.3
# 20           United States     614     2594620              23.7
# 21           United States      39     1608533               2.4
# 22           United States     431    12378771               3.5
# 23           United States      32    15905659               0.2
# 24           United States      44     1606378               2.7
# 25           United States     702    12603043               5.6
# 26           United States      65     3701886               1.8
# 27           United States     866     2531669              34.2
# 28           United States     728     2568722              28.3
# 29           United States     336     7802299               4.3
# ...                    ...     ...         ...               ...
# 2673         United States    1846    17537341              10.5
# 2674        North Carolina    1093     9535483              11.5
# 2675                Hawaii     123     1332213               9.2
# 2676            Washington     643     6052349              10.6
# 2677              Nebraska      66     1728292               3.8
# 2678         United States    9108   101304484               9.0
# 2679                Oregon     208     3421399               6.1
# 2680               Florida    3061    18801310              16.3
# 2681          South Dakota      20      754844               2.6
# 2682               Georgia     830     9155813               9.1
# 2683             Louisiana     365     4497267               8.1
# 2684         United States    3385    39944896               8.5
# 2685               Indiana     975     6516922              15.0
# 2686                Kansas     280     2871238               9.8
# 2687  District of Columbia      26      592228               4.4
# 2688             Minnesota     130     4919479               2.6
# 2689               Indiana     214     6080485               3.5
# 2690         United States    4323    41316519              10.5
# 2691                 Maine     162     1330509              12.2
# 2692         United States   13171   197324684               6.7
# 2693          Pennsylvania    3264    12802503              25.5
# 2694               Wyoming      98      582658              16.8
# 2695                 Texas    1598    21690325               7.4
# 2696           Mississippi     303     2947806              10.3
# 2697                 Texas    2191    23359580               9.4
# 2698             Tennessee    1090     6403353              17.0
# 2699           Connecticut     354     3458749              10.2
# 2700               Montana     125      964706              13.0
# 2701               Alabama     598     4833722              12.4
# 2702            Washington     850     6257305              13.6
#
#       Standard Error for Crude Rate  Low Confidence Limit for Crude Rate  \
# 0                               0.1                                  8.4
# 1                               0.4                                 15.9
# 2                               0.1                                  0.2
# 3                               0.3                                 21.1
# 4                               0.0                                  0.1
# 5                               0.2                                 12.5
# 6                               0.0                                  0.1
# 7                               0.2                                 11.5
# 8                               0.4                                  1.1
# 9                               1.0                                  9.7
# 10                              0.0                                  0.1
# 11                              0.2                                  0.9
# 12                              0.2                                  5.1
# 13                              0.0                                  0.1
# 14                              0.3                                  8.0
# 15                              0.1                                  2.6
# 16                              0.2                                 24.9
# 17                              0.2                                  3.6
# 18                              0.3                                  3.9
# 19                              0.6                                  2.2
# 20                              1.0                                 21.8
# 21                              0.4                                  1.7
# 22                              0.2                                  3.2
# 23                              0.0                                  0.1
# 24                              0.4                                  2.0
# 25                              0.2                                  5.2
# 26                              0.2                                  1.4
# 27                              1.2                                 31.9
# 28                              1.1                                 26.3
# 29                              0.2                                  3.8
# ...                             ...                                  ...
# 2673                            0.2                                 10.0
# 2674                            0.3                                 10.8
# 2675                            0.8                                  7.6
# 2676                            0.4                                  9.8
# 2677                            0.5                                  3.0
# 2678                            0.1                                  8.8
# 2679                            0.4                                  5.3
# 2680                            0.3                                 15.7
# 2681                            0.6                                  1.6
# 2682                            0.3                                  8.4
# 2683                            0.4                                  7.3
# 2684                            0.1                                  8.2
# 2685                            0.5                                 14.0
# 2686                            0.6                                  8.6
# 2687                            0.9                                  2.9
# 2688                            0.2                                  2.2
# 2689                            0.2                                  3.0
# 2690                            0.2                                 10.2
# 2691                            1.0                                 10.3
# 2692                            0.1                                  6.6
# 2693                            0.4                                 24.6
# 2694                            1.7                                 13.7
# 2695                            0.2                                  7.0
# 2696                            0.6                                  9.1
# 2697                            0.2                                  9.0
# 2698                            0.5                                 16.0
# 2699                            0.5                                  9.2
# 2700                            1.2                                 10.7
# 2701                            0.5                                 11.4
# 2702                            0.5                                 12.7
#
#       Upper Confidence Limit for Crude Rate  Age-adjusted Rate  \
# 0                                       8.9                NaN
# 1                                      17.3                NaN
# 2                                       0.5                NaN
# 3                                      22.1                NaN
# 4                                       0.2                NaN
# 5                                      13.4                NaN
# 6                                       0.3                NaN
# 7                                      12.3                NaN
# 8                                       2.6                NaN
# 9                                      13.8                NaN
# 10                                      0.2                NaN
# 11                                      1.7                NaN
# 12                                      5.7                NaN
# 13                                      0.2                NaN
# 14                                      9.0                NaN
# 15                                      3.1                NaN
# 16                                     25.9                NaN
# 17                                      4.5                NaN
# 18                                      4.9                NaN
# 19                                      4.8                NaN
# 20                                     25.5                NaN
# 21                                      3.3                NaN
# 22                                      3.8                NaN
# 23                                      0.3                NaN
# 24                                      3.7                NaN
# 25                                      6.0                NaN
# 26                                      2.2                NaN
# 27                                     36.5                NaN
# 28                                     30.4                NaN
# 29                                      4.8                NaN
# ...                                     ...                ...
# 2673                                   11.0               11.4
# 2674                                   12.1               11.4
# 2675                                   10.9                9.0
# 2676                                   11.4               10.4
# 2677                                    4.9                3.9
# 2678                                    9.2                8.8
# 2679                                    6.9                6.0
# 2680                                   16.9               16.4
# 2681                                    4.1                2.8
# 2682                                    9.7                8.9
# 2683                                    8.9                8.3
# 2684                                    8.8                8.5
# 2685                                   15.9               15.3
# 2686                                   10.9               10.1
# 2687                                    6.4                4.1
# 2688                                    3.1                2.6
# 2689                                    4.0                3.5
# 2690                                   10.8               10.5
# 2691                                   14.1               12.3
# 2692                                    6.8                6.6
# 2693                                   26.4               26.3
# 2694                                   20.5               17.2
# 2695                                    7.7                7.5
# 2696                                   11.4               10.5
# 2697                                    9.8                9.5
# 2698                                   18.0               17.2
# 2699                                   11.3               10.3
# 2700                                   15.2               12.8
# 2701                                   13.4               12.7
# 2702                                   14.5               13.0
#
#       Standard Error Age-adjusted Rate  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# ...                                ...
# 2673                               0.3
# 2674                               0.3
# 2675                               0.8
# 2676                               0.4
# 2677                               0.5
# 2678                               0.1
# 2679                               0.4
# 2680                               0.3
# 2681                               0.6
# 2682                               0.3
# 2683                               0.4
# 2684                               0.1
# 2685                               0.5
# 2686                               0.6
# 2687                               0.8
# 2688                               0.2
# 2689                               0.2
# 2690                               0.2
# 2691                               1.0
# 2692                               0.1
# 2693                               0.5
# 2694                               1.8
# 2695                               0.2
# 2696                               0.6
# 2697                               0.2
# 2698                               0.5
# 2699                               0.5
# 2700                               1.2
# 2701                               0.5
# 2702                               0.4
#
#       Lower Confidence Limit for Age-adjusted rate  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# ...                                            ...
# 2673                                          10.9
# 2674                                          10.7
# 2675                                           7.4
# 2676                                           9.6
# 2677                                           3.0
# 2678                                           8.6
# 2679                                           5.2
# 2680                                          15.8
# 2681                                           1.7
# 2682                                           8.3
# 2683                                           7.4
# 2684                                           8.2
# 2685                                          14.3
# 2686                                           8.9
# 2687                                           2.6
# 2688                                           2.2
# 2689                                           3.1
# 2690                                          10.2
# 2691                                          10.4
# 2692                                           6.4
# 2693                                          25.4
# 2694                                          13.9
# 2695                                           7.1
# 2696                                           9.3
# 2697                                           9.1
# 2698                                          16.1
# 2699                                           9.2
# 2700                                          10.5
# 2701                                          11.7
# 2702                                          12.2
#
#       Upper Confidence Limit for Age-adjusted Rate State Crude Rate in Range  \
# 0                                              NaN                       NaN
# 1                                              NaN                       NaN
# 2                                              NaN                       NaN
# 3                                              NaN                       NaN
# 4                                              NaN                       NaN
# 5                                              NaN                       NaN
# 6                                              NaN                       NaN
# 7                                              NaN                       NaN
# 8                                              NaN                       NaN
# 9                                              NaN                       NaN
# 10                                             NaN                       NaN
# 11                                             NaN                       NaN
# 12                                             NaN                       NaN
# 13                                             NaN                       NaN
# 14                                             NaN                       NaN
# 15                                             NaN                       NaN
# 16                                             NaN                       NaN
# 17                                             NaN                       NaN
# 18                                             NaN                       NaN
# 19                                             NaN                       NaN
# 20                                             NaN                       NaN
# 21                                             NaN                       NaN
# 22                                             NaN                       NaN
# 23                                             NaN                       NaN
# 24                                             NaN                       NaN
# 25                                             NaN                       NaN
# 26                                             NaN                       NaN
# 27                                             NaN                       NaN
# 28                                             NaN                       NaN
# 29                                             NaN                       NaN
# ...                                            ...                       ...
# 2673                                          11.9                 11.2–11.5
# 2674                                          12.1                  9.9–12.3
# 2675                                          10.6                     7–9.8
# 2676                                          11.2                  9.9–12.3
# 2677                                           5.0                     1.8–7
# 2678                                           9.0                   6.8–8.8
# 2679                                           6.8                     1.8–7
# 2680                                          17.0                 15.2–41.5
# 2681                                           4.3                     1.8–7
# 2682                                           9.6                     7–9.8
# 2683                                           9.1                     7–9.8
# 2684                                           8.8                   8.3–8.5
# 2685                                          16.3                 15.2–41.5
# 2686                                          11.3                  9.9–12.3
# 2687                                           6.0                     1.8–7
# 2688                                           3.0                     1.8–7
# 2689                                           4.0                     1.8–7
# 2690                                          10.8                 10.5–12.2
# 2691                                          14.3                  9.9–12.3
# 2692                                           6.7                   6.2–7.4
# 2693                                          27.3                 15.2–41.5
# 2694                                          21.1                 15.2–41.5
# 2695                                           7.9                     7–9.8
# 2696                                          11.7                  9.9–12.3
# 2697                                           9.9                     7–9.8
# 2698                                          18.2                 15.2–41.5
# 2699                                          11.3                  9.9–12.3
# 2700                                          15.0                 12.3–15.2
# 2701                                          13.8                 12.3–15.2
# 2702                                          13.9                 12.3–15.2
#
#       US Crude Rate  US Age-adjusted Rate
# 0              14.8                  14.7
# 1              13.2                  13.1
# 2              12.0                  11.9
# 3               8.9                   8.9
# 4              12.4                  12.3
# 5               6.8                   6.8
# 6               8.9                   8.9
# 7              12.4                  12.3
# 8              13.3                  13.2
# 9               6.8                   6.8
# 10              8.2                   8.2
# 11              9.4                   9.4
# 12             13.3                  13.2
# 13              6.2                   6.2
# 14             10.1                  10.1
# 15              6.8                   6.8
# 16             12.1                  11.9
# 17              6.0                   6.1
# 18             16.3                  16.3
# 19             13.3                  13.2
# 20              8.9                   8.9
# 21              6.0                   6.1
# 22              6.0                   6.1
# 23             14.8                  14.7
# 24             14.8                  14.7
# 25             12.0                  11.9
# 26             11.5                  11.5
# 27             16.3                  16.3
# 28             11.5                  11.5
# 29             13.9                  13.8
# ...             ...                   ...
# 2673            9.4                   9.4
# 2674           12.4                  12.3
# 2675           12.0                  11.9
# 2676            8.2                   8.2
# 2677            8.2                   8.2
# 2678           10.1                  10.1
# 2679            6.2                   6.2
# 2680           12.4                  12.3
# 2681            6.2                   6.2
# 2682           11.5                  11.5
# 2683            8.2                   8.2
# 2684           13.3                  13.2
# 2685           13.3                  13.2
# 2686           13.3                  13.2
# 2687           12.1                  11.9
# 2688            6.2                   6.2
# 2689            6.2                   6.2
# 2690           14.8                  14.7
# 2691           12.0                  11.9
# 2692            6.2                   6.2
# 2693           16.3                  16.3
# 2694           13.9                  13.8
# 2695            8.2                   8.2
# 2696           12.0                  11.9
# 2697           11.5                  11.5
# 2698           13.3                  13.2
# 2699            8.2                   8.2
# 2700           12.0                  11.9
# 2701           13.9                  13.8
# 2702           10.1                  10.1
#
# [2703 rows x 18 columns]

# %%
df['Age'].unique()
# Out:
# array(['15-24 years', 'Less than 15 years', '35-44 years', '45-54 years',
#        '75+ years', '55-64 years', '65-74 years', '25-34 years',
#        'All Ages'], dtype=object)

# %%
df.columns
# Out:
# Index(['Year', 'Sex', 'Age', 'Race and Hispanic Origin', 'State', 'Deaths',
#        'Population', 'Crude Death Rate', 'Standard Error for Crude Rate',
#        'Low Confidence Limit for Crude Rate',
#        'Upper Confidence Limit for Crude Rate', 'Age-adjusted Rate',
#        'Standard Error Age-adjusted Rate',
#        'Lower Confidence Limit for Age-adjusted rate',
#        'Upper Confidence Limit for Age-adjusted Rate',
#        'State Crude Rate in Range', 'US Crude Rate', 'US Age-adjusted Rate'],
#       dtype='object')

# %%
feats = df.drop(['Deaths'], axis=1)
labels = df['Deaths']

# %%
df0 = df.drop(['Age-adjusted Rate',
       'Standard Error Age-adjusted Rate',
       'Lower Confidence Limit for Age-adjusted rate',
       'Upper Confidence Limit for Age-adjusted Rate',
       'State Crude Rate in Range'], axis=1)
df0
# Out:
#       Year         Sex                 Age Race and Hispanic Origin  \
# 0     2014  Both Sexes         15-24 years    All Races-All Origins
# 1     2012        Male         15-24 years       Non-Hispanic White
# 2     2008        Male  Less than 15 years       Non-Hispanic Black
# 3     2003  Both Sexes         35-44 years       Non-Hispanic White
# 4     2010      Female  Less than 15 years       Non-Hispanic White
# 5     2001  Both Sexes         45-54 years       Non-Hispanic White
# 6     2003        Male  Less than 15 years       Non-Hispanic White
# 7     2010  Both Sexes         15-24 years       Non-Hispanic White
# 8     2011  Both Sexes           75+ years                 Hispanic
# 9     2001        Male         55-64 years       Non-Hispanic Black
# 10    2002      Female  Less than 15 years       Non-Hispanic White
# 11    2004      Female         15-24 years       Non-Hispanic Black
# 12    2011  Both Sexes         65-74 years    All Races-All Origins
# 13    2000  Both Sexes  Less than 15 years       Non-Hispanic Black
# 14    2005      Female         55-64 years       Non-Hispanic White
# 15    2001  Both Sexes           75+ years       Non-Hispanic White
# 16    2009  Both Sexes         45-54 years    All Races-All Origins
# 17    1999        Male         55-64 years       Non-Hispanic White
# 18    2015        Male           75+ years       Non-Hispanic White
# 19    2011        Male         65-74 years                 Hispanic
# 20    2003        Male         35-44 years       Non-Hispanic Black
# 21    1999  Both Sexes         65-74 years       Non-Hispanic Black
# 22    1999      Female         55-64 years    All Races-All Origins
# 23    2014      Female  Less than 15 years       Non-Hispanic White
# 24    2014  Both Sexes           75+ years       Non-Hispanic Black
# 25    2008      Female         15-24 years       Non-Hispanic White
# 26    2006      Female         15-24 years                 Hispanic
# 27    2015        Male         45-54 years       Non-Hispanic Black
# 28    2006        Male         35-44 years       Non-Hispanic Black
# 29    2013        Male           75+ years    All Races-All Origins
# ...    ...         ...                 ...                      ...
# 2673  2004        Male            All Ages       Non-Hispanic Black
# 2674  2010  Both Sexes            All Ages    All Races-All Origins
# 2675  2008  Both Sexes            All Ages    All Races-All Origins
# 2676  2002  Both Sexes            All Ages    All Races-All Origins
# 2677  2002  Both Sexes            All Ages    All Races-All Origins
# 2678  2005      Female            All Ages       Non-Hispanic White
# 2679  2000  Both Sexes            All Ages    All Races-All Origins
# 2680  2010  Both Sexes            All Ages    All Races-All Origins
# 2681  2000  Both Sexes            All Ages    All Races-All Origins
# 2682  2006  Both Sexes            All Ages    All Races-All Origins
# 2683  2002  Both Sexes            All Ages    All Races-All Origins
# 2684  2011  Both Sexes            All Ages       Non-Hispanic Black
# 2685  2011  Both Sexes            All Ages    All Races-All Origins
# 2686  2011  Both Sexes            All Ages    All Races-All Origins
# 2687  2009  Both Sexes            All Ages    All Races-All Origins
# 2688  2000  Both Sexes            All Ages    All Races-All Origins
# 2689  2000  Both Sexes            All Ages    All Races-All Origins
# 2690  2014  Both Sexes            All Ages       Non-Hispanic Black
# 2691  2008  Both Sexes            All Ages    All Races-All Origins
# 2692  2000  Both Sexes            All Ages       Non-Hispanic White
# 2693  2015  Both Sexes            All Ages    All Races-All Origins
# 2694  2013  Both Sexes            All Ages    All Races-All Origins
# 2695  2002  Both Sexes            All Ages    All Races-All Origins
# 2696  2008  Both Sexes            All Ages    All Races-All Origins
# 2697  2006  Both Sexes            All Ages    All Races-All Origins
# 2698  2011  Both Sexes            All Ages    All Races-All Origins
# 2699  2002  Both Sexes            All Ages    All Races-All Origins
# 2700  2007  Both Sexes            All Ages    All Races-All Origins
# 2701  2013  Both Sexes            All Ages    All Races-All Origins
# 2702  2005  Both Sexes            All Ages    All Races-All Origins
#
#                      State  Deaths  Population  Crude Death Rate  \
# 0            United States    3798    43979821               8.6
# 1            United States    2137    12857283              16.6
# 2            United States      15     4687984               0.3
# 3            United States    6533    30270056              21.6
# 4            United States      28    16460571               0.2
# 5            United States    3850    29733531              12.9
# 6            United States      38    18562010               0.2
# 7            United States    3020    25356574              11.9
# 8            United States      21     1213487               1.7
# 9            United States     129     1100021              11.7
# 10           United States      24    17779985               0.1
# 11           United States      38     3065345               1.2
# 12           United States    1204    22481738               5.4
# 13           United States      14     9411199               0.1
# 14           United States    1031    12166744               8.5
# 15           United States     418    14549012               2.9
# 16           United States   11390    44867088              25.4
# 17           United States     370     9153776               4.0
# 18           United States     291     6618453               4.4
# 19           United States      26      786108               3.3
# 20           United States     614     2594620              23.7
# 21           United States      39     1608533               2.4
# 22           United States     431    12378771               3.5
# 23           United States      32    15905659               0.2
# 24           United States      44     1606378               2.7
# 25           United States     702    12603043               5.6
# 26           United States      65     3701886               1.8
# 27           United States     866     2531669              34.2
# 28           United States     728     2568722              28.3
# 29           United States     336     7802299               4.3
# ...                    ...     ...         ...               ...
# 2673         United States    1846    17537341              10.5
# 2674        North Carolina    1093     9535483              11.5
# 2675                Hawaii     123     1332213               9.2
# 2676            Washington     643     6052349              10.6
# 2677              Nebraska      66     1728292               3.8
# 2678         United States    9108   101304484               9.0
# 2679                Oregon     208     3421399               6.1
# 2680               Florida    3061    18801310              16.3
# 2681          South Dakota      20      754844               2.6
# 2682               Georgia     830     9155813               9.1
# 2683             Louisiana     365     4497267               8.1
# 2684         United States    3385    39944896               8.5
# 2685               Indiana     975     6516922              15.0
# 2686                Kansas     280     2871238               9.8
# 2687  District of Columbia      26      592228               4.4
# 2688             Minnesota     130     4919479               2.6
# 2689               Indiana     214     6080485               3.5
# 2690         United States    4323    41316519              10.5
# 2691                 Maine     162     1330509              12.2
# 2692         United States   13171   197324684               6.7
# 2693          Pennsylvania    3264    12802503              25.5
# 2694               Wyoming      98      582658              16.8
# 2695                 Texas    1598    21690325               7.4
# 2696           Mississippi     303     2947806              10.3
# 2697                 Texas    2191    23359580               9.4
# 2698             Tennessee    1090     6403353              17.0
# 2699           Connecticut     354     3458749              10.2
# 2700               Montana     125      964706              13.0
# 2701               Alabama     598     4833722              12.4
# 2702            Washington     850     6257305              13.6
#
#       Standard Error for Crude Rate  Low Confidence Limit for Crude Rate  \
# 0                               0.1                                  8.4
# 1                               0.4                                 15.9
# 2                               0.1                                  0.2
# 3                               0.3                                 21.1
# 4                               0.0                                  0.1
# 5                               0.2                                 12.5
# 6                               0.0                                  0.1
# 7                               0.2                                 11.5
# 8                               0.4                                  1.1
# 9                               1.0                                  9.7
# 10                              0.0                                  0.1
# 11                              0.2                                  0.9
# 12                              0.2                                  5.1
# 13                              0.0                                  0.1
# 14                              0.3                                  8.0
# 15                              0.1                                  2.6
# 16                              0.2                                 24.9
# 17                              0.2                                  3.6
# 18                              0.3                                  3.9
# 19                              0.6                                  2.2
# 20                              1.0                                 21.8
# 21                              0.4                                  1.7
# 22                              0.2                                  3.2
# 23                              0.0                                  0.1
# 24                              0.4                                  2.0
# 25                              0.2                                  5.2
# 26                              0.2                                  1.4
# 27                              1.2                                 31.9
# 28                              1.1                                 26.3
# 29                              0.2                                  3.8
# ...                             ...                                  ...
# 2673                            0.2                                 10.0
# 2674                            0.3                                 10.8
# 2675                            0.8                                  7.6
# 2676                            0.4                                  9.8
# 2677                            0.5                                  3.0
# 2678                            0.1                                  8.8
# 2679                            0.4                                  5.3
# 2680                            0.3                                 15.7
# 2681                            0.6                                  1.6
# 2682                            0.3                                  8.4
# 2683                            0.4                                  7.3
# 2684                            0.1                                  8.2
# 2685                            0.5                                 14.0
# 2686                            0.6                                  8.6
# 2687                            0.9                                  2.9
# 2688                            0.2                                  2.2
# 2689                            0.2                                  3.0
# 2690                            0.2                                 10.2
# 2691                            1.0                                 10.3
# 2692                            0.1                                  6.6
# 2693                            0.4                                 24.6
# 2694                            1.7                                 13.7
# 2695                            0.2                                  7.0
# 2696                            0.6                                  9.1
# 2697                            0.2                                  9.0
# 2698                            0.5                                 16.0
# 2699                            0.5                                  9.2
# 2700                            1.2                                 10.7
# 2701                            0.5                                 11.4
# 2702                            0.5                                 12.7
#
#       Upper Confidence Limit for Crude Rate  US Crude Rate  \
# 0                                       8.9           14.8
# 1                                      17.3           13.2
# 2                                       0.5           12.0
# 3                                      22.1            8.9
# 4                                       0.2           12.4
# 5                                      13.4            6.8
# 6                                       0.3            8.9
# 7                                      12.3           12.4
# 8                                       2.6           13.3
# 9                                      13.8            6.8
# 10                                      0.2            8.2
# 11                                      1.7            9.4
# 12                                      5.7           13.3
# 13                                      0.2            6.2
# 14                                      9.0           10.1
# 15                                      3.1            6.8
# 16                                     25.9           12.1
# 17                                      4.5            6.0
# 18                                      4.9           16.3
# 19                                      4.8           13.3
# 20                                     25.5            8.9
# 21                                      3.3            6.0
# 22                                      3.8            6.0
# 23                                      0.3           14.8
# 24                                      3.7           14.8
# 25                                      6.0           12.0
# 26                                      2.2           11.5
# 27                                     36.5           16.3
# 28                                     30.4           11.5
# 29                                      4.8           13.9
# ...                                     ...            ...
# 2673                                   11.0            9.4
# 2674                                   12.1           12.4
# 2675                                   10.9           12.0
# 2676                                   11.4            8.2
# 2677                                    4.9            8.2
# 2678                                    9.2           10.1
# 2679                                    6.9            6.2
# 2680                                   16.9           12.4
# 2681                                    4.1            6.2
# 2682                                    9.7           11.5
# 2683                                    8.9            8.2
# 2684                                    8.8           13.3
# 2685                                   15.9           13.3
# 2686                                   10.9           13.3
# 2687                                    6.4           12.1
# 2688                                    3.1            6.2
# 2689                                    4.0            6.2
# 2690                                   10.8           14.8
# 2691                                   14.1           12.0
# 2692                                    6.8            6.2
# 2693                                   26.4           16.3
# 2694                                   20.5           13.9
# 2695                                    7.7            8.2
# 2696                                   11.4           12.0
# 2697                                    9.8           11.5
# 2698                                   18.0           13.3
# 2699                                   11.3            8.2
# 2700                                   15.2           12.0
# 2701                                   13.4           13.9
# 2702                                   14.5           10.1
#
#       US Age-adjusted Rate
# 0                     14.7
# 1                     13.1
# 2                     11.9
# 3                      8.9
# 4                     12.3
# 5                      6.8
# 6                      8.9
# 7                     12.3
# 8                     13.2
# 9                      6.8
# 10                     8.2
# 11                     9.4
# 12                    13.2
# 13                     6.2
# 14                    10.1
# 15                     6.8
# 16                    11.9
# 17                     6.1
# 18                    16.3
# 19                    13.2
# 20                     8.9
# 21                     6.1
# 22                     6.1
# 23                    14.7
# 24                    14.7
# 25                    11.9
# 26                    11.5
# 27                    16.3
# 28                    11.5
# 29                    13.8
# ...                    ...
# 2673                   9.4
# 2674                  12.3
# 2675                  11.9
# 2676                   8.2
# 2677                   8.2
# 2678                  10.1
# 2679                   6.2
# 2680                  12.3
# 2681                   6.2
# 2682                  11.5
# 2683                   8.2
# 2684                  13.2
# 2685                  13.2
# 2686                  13.2
# 2687                  11.9
# 2688                   6.2
# 2689                   6.2
# 2690                  14.7
# 2691                  11.9
# 2692                   6.2
# 2693                  16.3
# 2694                  13.8
# 2695                   8.2
# 2696                  11.9
# 2697                  11.5
# 2698                  13.2
# 2699                   8.2
# 2700                  11.9
# 2701                  13.8
# 2702                  10.1
#
# [2703 rows x 13 columns]

# %%
df0.columns
# Out:
# Index(['Year', 'Sex', 'Age', 'Race and Hispanic Origin', 'State', 'Deaths',
#        'Population', 'Crude Death Rate', 'Standard Error for Crude Rate',
#        'Low Confidence Limit for Crude Rate',
#        'Upper Confidence Limit for Crude Rate', 'US Crude Rate',
#        'US Age-adjusted Rate'],
#       dtype='object')

# %%
df0.dtypes
# Out:
# Year                                       int64
# Sex                                       object
# Age                                       object
# Race and Hispanic Origin                  object
# State                                     object
# Deaths                                     int64
# Population                                 int64
# Crude Death Rate                         float64
# Standard Error for Crude Rate            float64
# Low Confidence Limit for Crude Rate      float64
# Upper Confidence Limit for Crude Rate    float64
# US Crude Rate                            float64
# US Age-adjusted Rate                     float64
# dtype: object

# %%
df1 = df0.drop(['Crude Death Rate', 'Standard Error for Crude Rate',
       'Low Confidence Limit for Crude Rate',
       'Upper Confidence Limit for Crude Rate', 'US Crude Rate',
       'US Age-adjusted Rate'], axis=1)

# %%
df1.head()
# Out:
#    Year         Sex                 Age Race and Hispanic Origin  \
# 0  2014  Both Sexes         15-24 years    All Races-All Origins
# 1  2012        Male         15-24 years       Non-Hispanic White
# 2  2008        Male  Less than 15 years       Non-Hispanic Black
# 3  2003  Both Sexes         35-44 years       Non-Hispanic White
# 4  2010      Female  Less than 15 years       Non-Hispanic White
#
#            State  Deaths  Population
# 0  United States    3798    43979821
# 1  United States    2137    12857283
# 2  United States      15     4687984
# 3  United States    6533    30270056
# 4  United States      28    16460571

# %%
df1.dtypes
# Out:
# Year                         int64
# Sex                         object
# Age                         object
# Race and Hispanic Origin    object
# State                       object
# Deaths                       int64
# Population                   int64
# dtype: object

# %%
df1['Year'] = df1['Year'].astype('category')
df1['Sex'] = df1['Sex'].astype('category')
df1['Age'] = df1['Age'].astype('category')
df1['Race and Hispanic Origin'] = df1['Race and Hispanic Origin'].astype('category')
df1['State'] = df1['State'].astype('category')

df1.dtypes
# Out:
# Year                        category
# Sex                         category
# Age                         category
# Race and Hispanic Origin    category
# State                       category
# Deaths                         int64
# Population                     int64
# dtype: object

# %%
df1o = pd.get_dummies(df1, columns=['Year', 'Sex', 'Age', 'Race and Hispanic Origin', 'State'])
df1o.columns;

# %% [markdown]
# ## Decision Tree Model
#
# ### Using MSE

# %%
dTree_mse = DecisionTreeRegressor(random_state=0, criterion='mse')
dTree_mse.fit(df1o.drop(['Deaths'],axis=1), df1o['Deaths'])
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
dTree_mse.feature_importances_;

# %%
for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
    print(df1o.drop(['Deaths'],axis=1).columns[i], "has importance", dTree_mse.feature_importances_[i])
# Out:
# Population has importance 0.8955368908956396
# Year_1999 has importance 0.0005975239307293114
# Year_2000 has importance 0.0009716861842844031
# Year_2001 has importance 0.0008172263270101003
# Year_2002 has importance 0.0010463976851457632
# Year_2003 has importance 0.0004861932131133754
# Year_2004 has importance 0.00032080314858082764
# Year_2005 has importance 0.00027689872706007873
# Year_2006 has importance 0.00022656654714549722
# Year_2007 has importance 8.07143771741021e-05
# Year_2008 has importance 5.870111100469168e-05
# Year_2009 has importance 3.614389043082414e-05
# Year_2010 has importance 7.288251008580415e-05
# Year_2011 has importance 4.603711181064502e-05
# Year_2012 has importance 4.337929483183987e-05
# Year_2013 has importance 9.424763291164542e-05
# Year_2014 has importance 0.0005012307938595268
# Year_2015 has importance 0.003183083192992117
# Sex_Both Sexes has importance 0.0006049744404203129
# Sex_Female has importance 0.02250359378213672
# Sex_Male has importance 0.006126607895009445
# Age_15-24 years has importance 0.00028998751775875103
# Age_25-34 years has importance 0.006818048804128908
# Age_35-44 years has importance 0.009980744757009233
# Age_45-54 years has importance 0.013313810521680548
# Age_55-64 years has importance 0.0024354227276619234
# Age_65-74 years has importance 1.4221414425668768e-05
# Age_75+ years has importance 5.591262248744719e-06
# Age_All Ages has importance 0.00014995379892884317
# Age_Less than 15 years has importance 0.019191535627220313
# Race and Hispanic Origin_All Races-All Origins has importance 0.00889187582610047
# Race and Hispanic Origin_Hispanic has importance 0.00011069952101322493
# Race and Hispanic Origin_Non-Hispanic Black has importance 0.000322419117256687
# Race and Hispanic Origin_Non-Hispanic White has importance 0.0037277228754972716
# State_Alabama has importance 6.674955342901142e-06
# State_Alaska has importance 4.709252503259911e-08
# State_Arizona has importance 1.1285999176557571e-06
# State_Arkansas has importance 1.499543394200128e-07
# State_California has importance 0.0001568042998266502
# State_Colorado has importance 2.487293478260988e-06
# State_Connecticut has importance 1.996252660272461e-08
# State_Delaware has importance 3.993139013933267e-07
# State_District of Columbia has importance 0.0
# State_Florida has importance 0.00015940282062815056
# State_Georgia has importance 6.203840233634476e-06
# State_Hawaii has importance 1.2737834726277096e-07
# State_Idaho has importance 2.107504510846671e-07
# State_Illinois has importance 2.3591590235170907e-05
# State_Indiana has importance 1.0961751389215019e-05
# State_Iowa has importance 5.61527304761252e-06
# State_Kansas has importance 1.2022098034023682e-08
# State_Kentucky has importance 9.826886648114608e-06
# State_Louisiana has importance 5.924608854070317e-07
# State_Maine has importance 3.541864913155824e-08
# State_Maryland has importance 1.9975122736841357e-06
# State_Massachusetts has importance 1.1040678624706203e-05
# State_Michigan has importance 1.7542568526249247e-05
# State_Minnesota has importance 2.4528778872076108e-05
# State_Mississippi has importance 6.77767992396979e-10
# State_Missouri has importance 1.299160577205351e-06
# State_Montana has importance 9.187354839512932e-08
# State_Nebraska has importance 5.666762085571909e-06
# State_Nevada has importance 6.683536556550728e-06
# State_New Hampshire has importance 7.809955078638454e-07
# State_New Jersey has importance 1.8475979571151497e-06
# State_New Mexico has importance 1.8004990203326957e-06
# State_New York has importance 3.993170392180138e-05
# State_North Carolina has importance 7.933861749930321e-07
# State_North Dakota has importance 4.799756351898185e-07
# State_Ohio has importance 1.6884547189680105e-05
# State_Oklahoma has importance 1.1803515782284504e-05
# State_Oregon has importance 9.371372518278188e-07
# State_Pennsylvania has importance 3.0093410953786506e-06
# State_Rhode Island has importance 1.5555528501051764e-08
# State_South Carolina has importance 4.6079186576410346e-08
# State_South Dakota has importance 2.6666846980544506e-07
# State_Tennessee has importance 2.716201920213767e-06
# State_Texas has importance 3.204570624680139e-06
# State_United States has importance 0.0005619362250627904
# State_Utah has importance 3.481642628674503e-06
# State_Vermont has importance 0.0
# State_Virginia has importance 5.514464976644697e-07
# State_Washington has importance 3.6179347520298596e-06
# State_West Virginia has importance 9.036906565289548e-12
# State_Wisconsin has importance 8.935291145257727e-06
# State_Wyoming has importance 0.0

# %%
tots_DTmse = [['Year', 0], ['Sex', 0], ['Age', 0], ['Race and Hispanic Origin', 0], ['State', 0]]
for elem in tots_DTmse:
    for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
        if elem[0] in df1o.drop(['Deaths'],axis=1).columns[i]:
            elem[1] = elem[1] + dTree_mse.feature_importances_[i]

# %%
tots_DTmse
# Out:
# [['Year', 0.008859715678170555],
#  ['Sex', 0.029235176117566476],
#  ['Age', 0.05219931643106293],
#  ['Race and Hispanic Origin', 0.013052717339867653],
#  ['State', 0.0011161835376927336]]

# %% [markdown]
# ### Freidman MSE

# %%
dTree_fmse = DecisionTreeRegressor(random_state=0, criterion='friedman_mse')
dTree_fmse.fit(df1o.drop(['Deaths'],axis=1), df1o['Deaths'])
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=None,
#            max_features=None, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#            splitter='best')

# %%
dTree_fmse.feature_importances_;

# %%
for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
    print(df1o.drop(['Deaths'],axis=1).columns[i], "has importance", dTree_fmse.feature_importances_[i])
# Out:
# Population has importance 0.8960823209838781
# Year_1999 has importance 0.0009942132149369808
# Year_2000 has importance 0.0009673492893829504
# Year_2001 has importance 0.0009700849463314784
# Year_2002 has importance 0.0010683016527733055
# Year_2003 has importance 0.0004593562012992512
# Year_2004 has importance 0.000363601234455017
# Year_2005 has importance 0.0003786923609807
# Year_2006 has importance 0.00012548103196157354
# Year_2007 has importance 8.155434834424169e-05
# Year_2008 has importance 5.6848515057301824e-05
# Year_2009 has importance 3.854060725818639e-05
# Year_2010 has importance 8.435539819474644e-05
# Year_2011 has importance 4.451179243350439e-05
# Year_2012 has importance 4.275716162950531e-05
# Year_2013 has importance 0.00013558100783502586
# Year_2014 has importance 0.0005985754702824375
# Year_2015 has importance 0.0033717541859635113
# Sex_Both Sexes has importance 0.0022451736677538093
# Sex_Female has importance 0.022503207427365383
# Sex_Male has importance 0.006174795450125016
# Age_15-24 years has importance 0.00030383566681688515
# Age_25-34 years has importance 0.006821135639710388
# Age_35-44 years has importance 0.009981372750365763
# Age_45-54 years has importance 0.013313681500302401
# Age_55-64 years has importance 0.002551946171141833
# Age_65-74 years has importance 1.380402682213775e-05
# Age_75+ years has importance 1.1005031987834618e-05
# Age_All Ages has importance 0.00014513730854787287
# Age_Less than 15 years has importance 0.01919153562722032
# Race and Hispanic Origin_All Races-All Origins has importance 0.0015402447993101453
# Race and Hispanic Origin_Hispanic has importance 0.00011025892145772487
# Race and Hispanic Origin_Non-Hispanic Black has importance 0.0002940498079226651
# Race and Hispanic Origin_Non-Hispanic White has importance 0.007829090276904649
# State_Alabama has importance 6.6649334135202395e-06
# State_Alaska has importance 4.709252503259913e-08
# State_Arizona has importance 1.1285999176557576e-06
# State_Arkansas has importance 1.5979251836742387e-07
# State_California has importance 0.00015680429982665024
# State_Colorado has importance 2.487293478260989e-06
# State_Connecticut has importance 0.0
# State_Delaware has importance 3.9931390139332685e-07
# State_District of Columbia has importance 0.0
# State_Florida has importance 0.00015940282062815061
# State_Georgia has importance 6.211973449543239e-06
# State_Hawaii has importance 1.2737834726277101e-07
# State_Idaho has importance 2.107504510846672e-07
# State_Illinois has importance 2.3591590235170914e-05
# State_Indiana has importance 1.0961751389215022e-05
# State_Iowa has importance 5.615273047612522e-06
# State_Kansas has importance 1.1985950407762527e-08
# State_Kentucky has importance 9.826886648114611e-06
# State_Louisiana has importance 7.519622862843945e-07
# State_Maine has importance 5.060968906780998e-08
# State_Maryland has importance 1.9975122736841365e-06
# State_Massachusetts has importance 1.1043573447109268e-05
# State_Michigan has importance 1.7542568526249254e-05
# State_Minnesota has importance 2.4353642116689707e-05
# State_Mississippi has importance 1.1826145038209879e-07
# State_Missouri has importance 1.2067286870138155e-06
# State_Montana has importance 9.187354839512935e-08
# State_Nebraska has importance 5.666762085571911e-06
# State_Nevada has importance 6.68353655655073e-06
# State_New Hampshire has importance 7.809955078638457e-07
# State_New Jersey has importance 2.0824918596250207e-06
# State_New Mexico has importance 1.840553602532248e-06
# State_New York has importance 3.307165904942492e-05
# State_North Carolina has importance 1.3890743548989276e-06
# State_North Dakota has importance 4.799756351898187e-07
# State_Ohio has importance 1.6884547189680112e-05
# State_Oklahoma has importance 1.1759605453283766e-05
# State_Oregon has importance 2.2816482106115807e-07
# State_Pennsylvania has importance 3.009341095378652e-06
# State_Rhode Island has importance 1.555552850105177e-08
# State_South Carolina has importance 1.662111112568751e-06
# State_South Dakota has importance 2.666684698054451e-07
# State_Tennessee has importance 2.7259798531174114e-06
# State_Texas has importance 0.0
# State_United States has importance 0.0005599057756143242
# State_Utah has importance 3.481642628674504e-06
# State_Vermont has importance 0.0
# State_Virginia has importance 5.5144649766447e-07
# State_Washington has importance 3.617907641310165e-06
# State_West Virginia has importance 9.036906565289551e-12
# State_Wisconsin has importance 8.934251901002723e-06
# State_Wyoming has importance 0.0

# %%
tots_DTfmse = [['Year', 0], ['Sex', 0], ['Age', 0], ['Race and Hispanic Origin', 0], ['State', 0]]
for elem in tots_DTfmse:
    for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
        if elem[0] in df1o.drop(['Deaths'],axis=1).columns[i]:
            elem[1] = elem[1] + dTree_fmse.feature_importances_[i]

# %%
tots_DTfmse
# Out:
# [['Year', 0.009781558419119717],
#  ['Sex', 0.030923176545244208],
#  ['Age', 0.05233345372291544],
#  ['Race and Hispanic Origin', 0.009773643805595185],
#  ['State', 0.0011058465232472547]]

# %% [markdown]
# ### MAE

# %%
dTree_mae = DecisionTreeRegressor(random_state=0, criterion='mae')
dTree_mae.fit(df1o.drop(['Deaths'],axis=1), df1o['Deaths'])
# Out:
# DecisionTreeRegressor(criterion='mae', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
dTree_mae.feature_importances_;

# %%
for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
    print(df1o.drop(['Deaths'],axis=1).columns[i], "has importance", dTree_mae.feature_importances_[i])
# Out:
# Population has importance 0.6748110877558902
# Year_1999 has importance 0.007477949870776992
# Year_2000 has importance 0.0075138661857630734
# Year_2001 has importance 0.00769712593752941
# Year_2002 has importance 0.00654996749140767
# Year_2003 has importance 0.004491486643349909
# Year_2004 has importance 0.002758848990286367
# Year_2005 has importance 0.0047569644655663145
# Year_2006 has importance 0.003214942917940956
# Year_2007 has importance 0.0016084450940152813
# Year_2008 has importance 0.000906346045040357
# Year_2009 has importance 0.0011069148642698654
# Year_2010 has importance 0.0017992775627967555
# Year_2011 has importance 0.003167559345760522
# Year_2012 has importance 0.0026932908972696025
# Year_2013 has importance 0.004981982342587553
# Year_2014 has importance 0.007494177121523716
# Year_2015 has importance 0.0107106345828677
# Sex_Both Sexes has importance 0.008812911698874147
# Sex_Female has importance 0.02462517755316858
# Sex_Male has importance 0.014492882186914125
# Age_15-24 years has importance 0.017574978012075238
# Age_25-34 years has importance 0.014532260315392842
# Age_35-44 years has importance 0.01968170788568659
# Age_45-54 years has importance 0.02385881859123663
# Age_55-64 years has importance 0.003496215264217505
# Age_65-74 years has importance 0.0009822895785350251
# Age_75+ years has importance 0.0005354992746418915
# Age_All Ages has importance 0.022485127724690638
# Age_Less than 15 years has importance 0.061517507580830626
# Race and Hispanic Origin_All Races-All Origins has importance 0.00838992136274288
# Race and Hispanic Origin_Hispanic has importance 0.00298170323387471
# Race and Hispanic Origin_Non-Hispanic Black has importance 0.002217075178689076
# Race and Hispanic Origin_Non-Hispanic White has importance 0.004942387850765547
# State_Alabama has importance 0.0003810158475330791
# State_Alaska has importance 3.6781768359241038e-06
# State_Arizona has importance 0.00011986529218246783
# State_Arkansas has importance 5.322538244925467e-05
# State_California has importance 0.0005101847634770021
# State_Colorado has importance 0.00018304338842304655
# State_Connecticut has importance 3.872903844884791e-05
# State_Delaware has importance 3.396904489647554e-05
# State_District of Columbia has importance 0.0
# State_Florida has importance 0.0015305542904310056
# State_Georgia has importance 0.0003016105005457765
# State_Hawaii has importance 1.9472700896068783e-05
# State_Idaho has importance 3.418540823976519e-05
# State_Illinois has importance 0.0008431679487997782
# State_Indiana has importance 0.0003057214040682797
# State_Iowa has importance 0.00025227965827573557
# State_Kansas has importance 1.298180059737919e-06
# State_Kentucky has importance 0.0004007049117724376
# State_Louisiana has importance 1.860724752291017e-05
# State_Maine has importance 1.3198163940668842e-05
# State_Maryland has importance 0.00014236707988459177
# State_Massachusetts has importance 0.00021203607642386008
# State_Michigan has importance 1.5145434030275718e-06
# State_Minnesota has importance 0.0005326865511791269
# State_Mississippi has importance 5.409083582241329e-05
# State_Missouri has importance 0.00010277258806258529
# State_Montana has importance 1.9905427582648087e-05
# State_Nebraska has importance 0.0003695485903387276
# State_Nevada has importance 0.0002038142693788533
# State_New Hampshire has importance 7.053444991242692e-05
# State_New Jersey has importance 6.923626985268901e-05
# State_New Mexico has importance 0.0
# State_New York has importance 0.0002907923333812938
# State_North Carolina has importance 4.067630853845479e-05
# State_North Dakota has importance 0.00010666712824179899
# State_Ohio has importance 0.00013219800274997807
# State_Oklahoma has importance 0.00023064332394677025
# State_Oregon has importance 3.764722173239964e-05
# State_Pennsylvania has importance 0.00045501211093814054
# State_Rhode Island has importance 4.392175868779964e-05
# State_South Carolina has importance 0.00028689779320208007
# State_South Dakota has importance 6.317809624057872e-05
# State_Tennessee has importance 0.00022804696382729443
# State_Texas has importance 0.00017222522125856388
# State_United States has importance 0.0059499919404654615
# State_Utah has importance 0.0001713597678854053
# State_Vermont has importance 2.2069061015544595e-05
# State_Virginia has importance 1.5145434030275718e-06
# State_Washington has importance 2.1419970985675662e-05
# State_West Virginia has importance 0.0
# State_Wisconsin has importance 4.5436302090827156e-05
# State_Wyoming has importance 9.952713791324044e-06

# %%
tots_DTmae = [['Year', 0], ['Sex', 0], ['Age', 0], ['Race and Hispanic Origin', 0], ['State', 0]]
for elem in tots_DTmae:
    for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
        if elem[0] in df1o.drop(['Deaths'],axis=1).columns[i]:
            elem[1] = elem[1] + dTree_mae.feature_importances_[i]

# %%
tots_DTmae
# Out:
# [['Year', 0.07892978035875205],
#  ['Sex', 0.047930971438956846],
#  ['Age', 0.16466440422730697],
#  ['Race and Hispanic Origin', 0.018531087626072213],
#  ['State', 0.01513266859302163]]

# %% [markdown]
# ## Random Forests
#
# ### MSE

# %%
rf_mse = RandomForestRegressor(n_estimators=10000, n_jobs=8, criterion='mse', random_state=0)
rf_mse.fit(df1o.drop(['Deaths'],axis=1), df1o['Deaths'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=8,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
rf_mse.feature_importances_;

# %%
for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
    print(df1o.drop(['Deaths'],axis=1).columns[i], "has importance", rf_mse.feature_importances_[i])
# Out:
# Population has importance 0.8892889411052245
# Year_1999 has importance 0.003927399919424608
# Year_2000 has importance 0.0035375685505226856
# Year_2001 has importance 0.0024984933683859173
# Year_2002 has importance 0.0011347700467770803
# Year_2003 has importance 0.0006633078760154232
# Year_2004 has importance 0.0005109139076380317
# Year_2005 has importance 0.0004961837670953116
# Year_2006 has importance 0.0003327725491594124
# Year_2007 has importance 0.00015788936060293578
# Year_2008 has importance 0.00012146766274621428
# Year_2009 has importance 0.00011863974378093672
# Year_2010 has importance 0.00019872472095456832
# Year_2011 has importance 0.00035179539281850663
# Year_2012 has importance 0.000361738995733794
# Year_2013 has importance 0.0007196209951316378
# Year_2014 has importance 0.0018057145126137825
# Year_2015 has importance 0.006361912195503464
# Sex_Both Sexes has importance 0.001669461940752128
# Sex_Female has importance 0.01871268170762662
# Sex_Male has importance 0.007197540673013594
# Age_15-24 years has importance 0.003694331593885783
# Age_25-34 years has importance 0.004239403592460932
# Age_35-44 years has importance 0.007950752448512538
# Age_45-54 years has importance 0.012015446095514512
# Age_55-64 years has importance 0.001721583366481947
# Age_65-74 years has importance 0.0002567115628461004
# Age_75+ years has importance 0.00011340327926054626
# Age_All Ages has importance 0.002140369792862486
# Age_Less than 15 years has importance 0.018157314063867308
# Race and Hispanic Origin_All Races-All Origins has importance 0.002927981200154669
# Race and Hispanic Origin_Hispanic has importance 0.0013725444618559765
# Race and Hispanic Origin_Non-Hispanic Black has importance 0.0003571728700816399
# Race and Hispanic Origin_Non-Hispanic White has importance 0.0038385279775237408
# State_Alabama has importance 5.975666288070839e-06
# State_Alaska has importance 1.5552187414525345e-07
# State_Arizona has importance 4.4373293302795574e-06
# State_Arkansas has importance 5.393975059177899e-07
# State_California has importance 4.761268421715128e-05
# State_Colorado has importance 3.2919588177944563e-06
# State_Connecticut has importance 5.402402199560793e-07
# State_Delaware has importance 1.662249285871226e-07
# State_District of Columbia has importance 3.760379492172892e-08
# State_Florida has importance 0.0001850994753581655
# State_Georgia has importance 6.921101995447941e-06
# State_Hawaii has importance 1.0126879984908629e-07
# State_Idaho has importance 1.3091837486543894e-07
# State_Illinois has importance 4.1487834642281807e-05
# State_Indiana has importance 7.721519936976892e-06
# State_Iowa has importance 4.7147100480249485e-06
# State_Kansas has importance 6.563779161804315e-07
# State_Kentucky has importance 1.4604381531056456e-05
# State_Louisiana has importance 1.4385515365525495e-06
# State_Maine has importance 5.284801377633961e-08
# State_Maryland has importance 3.7368557404404153e-06
# State_Massachusetts has importance 7.258848056816528e-06
# State_Michigan has importance 9.080523463582625e-06
# State_Minnesota has importance 1.7733661068105697e-05
# State_Mississippi has importance 7.33200305498799e-07
# State_Missouri has importance 2.0269332180695783e-06
# State_Montana has importance 1.2393532365519294e-07
# State_Nebraska has importance 2.93302877016132e-06
# State_Nevada has importance 8.555339375889533e-06
# State_New Hampshire has importance 5.788465752819594e-07
# State_New Jersey has importance 1.8148212196935525e-06
# State_New Mexico has importance 5.198871120128393e-06
# State_New York has importance 1.7383691748053935e-05
# State_North Carolina has importance 2.4775609735342576e-06
# State_North Dakota has importance 4.7636490769855725e-07
# State_Ohio has importance 1.0817315793715225e-05
# State_Oklahoma has importance 5.995549081022009e-06
# State_Oregon has importance 1.2551688620613605e-06
# State_Pennsylvania has importance 1.8264761464092623e-05
# State_Rhode Island has importance 5.528804573008991e-07
# State_South Carolina has importance 2.3377134269468e-06
# State_South Dakota has importance 2.454054673869605e-07
# State_Tennessee has importance 4.936383235761367e-06
# State_Texas has importance 8.46266343507254e-06
# State_United States has importance 0.0005668858213787563
# State_Utah has importance 6.763372687962457e-06
# State_Vermont has importance 3.002141735792161e-08
# State_Virginia has importance 1.6142409592941207e-06
# State_Washington has importance 3.033312529494999e-06
# State_West Virginia has importance 5.974952228380125e-06
# State_Wisconsin has importance 3.940077878177628e-06
# State_Wyoming has importance 1.0965867766944152e-08

# %%
tots_RFmse = [['Year', 0], ['Sex', 0], ['Age', 0], ['Race and Hispanic Origin', 0], ['State', 0]]
for elem in tots_RFmse:
    for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
        if elem[0] in df1o.drop(['Deaths'],axis=1).columns[i]:
            elem[1] = elem[1] + rf_mse.feature_importances_[i]

# %%
tots_RFmse
# Out:
# [['Year', 0.023298913564904312],
#  ['Sex', 0.027579684321392343],
#  ['Age', 0.05028931579569215],
#  ['Race and Hispanic Origin', 0.008496226509616026],
#  ['State', 0.0010469187031671625]]

# %%
huh= [['Year', 0.023630291051921028],
 ['Sex', 0.02763024027599163],
 ['Age', 0.0507013106827508],
 ['Race and Hispanic Origin', 0.008424596871325608],
 ['State', 0.0010475050266154822]]

# %% [markdown]
# ### MAE

# %%
rf_mae = RandomForestRegressor(n_estimators=10000, n_jobs=8, criterion='mae', random_state=0)
rf_mae.fit(df1o.drop(['Deaths'],axis=1), df1o['Deaths'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mae', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=8,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
rf_mae.feature_importances_;

# %%
for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
    print(df1o.drop(['Deaths'],axis=1).columns[i], "has importance", rf_mae.feature_importances_[i])
# Out:
# Population has importance 0.6425088186564889
# Year_1999 has importance 0.011654844396037884
# Year_2000 has importance 0.01133945781103143
# Year_2001 has importance 0.010112625869549998
# Year_2002 has importance 0.00641651397931943
# Year_2003 has importance 0.0046856536147907085
# Year_2004 has importance 0.004082343878191998
# Year_2005 has importance 0.0038873257537108733
# Year_2006 has importance 0.0036269414811978544
# Year_2007 has importance 0.002446229401200715
# Year_2008 has importance 0.0019185290862902952
# Year_2009 has importance 0.002098718673989757
# Year_2010 has importance 0.0026898578275783803
# Year_2011 has importance 0.003203462414693287
# Year_2012 has importance 0.0032622135441710215
# Year_2013 has importance 0.004947827560341437
# Year_2014 has importance 0.008074804180667413
# Year_2015 has importance 0.015411495502935293
# Sex_Both Sexes has importance 0.010881445028548873
# Sex_Female has importance 0.024333051247794987
# Sex_Male has importance 0.021135837179143278
# Age_15-24 years has importance 0.01314669723351301
# Age_25-34 years has importance 0.01506198918872276
# Age_35-44 years has importance 0.02607359399612186
# Age_45-54 years has importance 0.028067071793265227
# Age_55-64 years has importance 0.006125348539514505
# Age_65-74 years has importance 0.0022861973858825275
# Age_75+ years has importance 0.002404617474128881
# Age_All Ages has importance 0.010131514681715664
# Age_Less than 15 years has importance 0.061361882694721155
# Race and Hispanic Origin_All Races-All Origins has importance 0.00695974987221272
# Race and Hispanic Origin_Hispanic has importance 0.004006967691505294
# Race and Hispanic Origin_Non-Hispanic Black has importance 0.0026630997242119417
# Race and Hispanic Origin_Non-Hispanic White has importance 0.007875035643138581
# State_Alabama has importance 0.0002724579298445907
# State_Alaska has importance 2.043262666938832e-05
# State_Arizona has importance 0.0002172074159468046
# State_Arkansas has importance 5.6787370620345046e-05
# State_California has importance 0.0003676538047235338
# State_Colorado has importance 0.0001764793901276054
# State_Connecticut has importance 4.179640778663205e-05
# State_Delaware has importance 2.0175597936357415e-05
# State_District of Columbia has importance 1.3505944326674966e-05
# State_Florida has importance 0.0016199130285020076
# State_Georgia has importance 0.00026843314348791203
# State_Hawaii has importance 2.828419484270236e-05
# State_Idaho has importance 2.7635812154014517e-05
# State_Illinois has importance 0.0006710049240913839
# State_Indiana has importance 0.00026808389396062326
# State_Iowa has importance 0.00023104634152011804
# State_Kansas has importance 3.4810717433410816e-05
# State_Kentucky has importance 0.00034101468731095245
# State_Louisiana has importance 8.539534380804347e-05
# State_Maine has importance 1.7846055107402387e-05
# State_Maryland has importance 0.0001632528034611667
# State_Massachusetts has importance 0.00024204651934471902
# State_Michigan has importance 0.0001600713174009045
# State_Minnesota has importance 0.0005713137199328046
# State_Mississippi has importance 5.726879203842233e-05
# State_Missouri has importance 0.00015902098471416435
# State_Montana has importance 2.566882740871116e-05
# State_Nebraska has importance 0.00023927321706294542
# State_Nevada has importance 0.0003380875449421985
# State_New Hampshire has importance 5.5992492963117824e-05
# State_New Jersey has importance 9.355218510130459e-05
# State_New Mexico has importance 0.00024375009530778788
# State_New York has importance 0.00031727496720895354
# State_North Carolina has importance 0.00013846290191404188
# State_North Dakota has importance 0.00010803406742550641
# State_Ohio has importance 0.0001548504893059248
# State_Oklahoma has importance 0.0002923930925527099
# State_Oregon has importance 0.00011416650737276657
# State_Pennsylvania has importance 0.00028023274891014727
# State_Rhode Island has importance 4.4853233028379015e-05
# State_South Carolina has importance 0.00015558415402586783
# State_South Dakota has importance 5.573313157683508e-05
# State_Tennessee has importance 0.00026154830254981
# State_Texas has importance 0.00020745896974182115
# State_United States has importance 0.004899748078790824
# State_Utah has importance 0.00031015318545349406
# State_Vermont has importance 1.4927147785255377e-05
# State_Virginia has importance 8.629527865642827e-05
# State_Washington has importance 0.00017881408248930465
# State_West Virginia has importance 0.00019913308982295064
# State_Wisconsin has importance 0.00016345003489904222
# State_Wyoming has importance 5.86040028563568e-06

# %%
tots_RFmae = [['Year', 0], ['Sex', 0], ['Age', 0], ['Race and Hispanic Origin', 0], ['State', 0]]
for elem in tots_RFmae:
    for i in range(len(df1o.drop(['Deaths'],axis=1).columns)):
        if elem[0] in df1o.drop(['Deaths'],axis=1).columns[i]:
            elem[1] = elem[1] + rf_mae.feature_importances_[i]

# %%
tots_RFmae
# Out:
# [['Year', 0.09985884497569779],
#  ['Sex', 0.05635033345548714],
#  ['Age', 0.1646589129875856],
#  ['Race and Hispanic Origin', 0.02150485293106854],
#  ['State', 0.015118236993674447]]
