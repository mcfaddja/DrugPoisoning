# %% [markdown]
# # By Gender

# %%
import numpy as np
import pandas as pd
import copy as cp
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
df0 = pd.read_csv("data.csv")
df0.shape
# Out:
# (2703, 18)

# %%
df1 = df0.drop(['Age-adjusted Rate',
                'Standard Error Age-adjusted Rate',
                'Lower Confidence Limit for Age-adjusted rate',
                'Upper Confidence Limit for Age-adjusted Rate',
                'State Crude Rate in Range',
                'US Age-adjusted Rate'], axis=1)
df1.head()
# Out:
#    Year         Sex                 Age Race and Hispanic Origin  \
# 0  2014  Both Sexes         15-24 years    All Races-All Origins
# 1  2012        Male         15-24 years       Non-Hispanic White
# 2  2008        Male  Less than 15 years       Non-Hispanic Black
# 3  2003  Both Sexes         35-44 years       Non-Hispanic White
# 4  2010      Female  Less than 15 years       Non-Hispanic White
#
#            State  Deaths  Population  Crude Death Rate  \
# 0  United States    3798    43979821               8.6
# 1  United States    2137    12857283              16.6
# 2  United States      15     4687984               0.3
# 3  United States    6533    30270056              21.6
# 4  United States      28    16460571               0.2
#
#    Standard Error for Crude Rate  Low Confidence Limit for Crude Rate  \
# 0                            0.1                                  8.4
# 1                            0.4                                 15.9
# 2                            0.1                                  0.2
# 3                            0.3                                 21.1
# 4                            0.0                                  0.1
#
#    Upper Confidence Limit for Crude Rate  US Crude Rate
# 0                                    8.9           14.8
# 1                                   17.3           13.2
# 2                                    0.5           12.0
# 3                                   22.1            8.9
# 4                                    0.2           12.4

# %%
df = df1.loc[df1['Sex']!='Both Sexes']
df.head()
# Out:
#    Year     Sex                 Age Race and Hispanic Origin          State  \
# 1  2012    Male         15-24 years       Non-Hispanic White  United States
# 2  2008    Male  Less than 15 years       Non-Hispanic Black  United States
# 4  2010  Female  Less than 15 years       Non-Hispanic White  United States
# 6  2003    Male  Less than 15 years       Non-Hispanic White  United States
# 9  2001    Male         55-64 years       Non-Hispanic Black  United States
#
#    Deaths  Population  Crude Death Rate  Standard Error for Crude Rate  \
# 1    2137    12857283              16.6                            0.4
# 2      15     4687984               0.3                            0.1
# 4      28    16460571               0.2                            0.0
# 6      38    18562010               0.2                            0.0
# 9     129     1100021              11.7                            1.0
#
#    Low Confidence Limit for Crude Rate  Upper Confidence Limit for Crude Rate  \
# 1                                 15.9                                   17.3
# 2                                  0.2                                    0.5
# 4                                  0.1                                    0.2
# 6                                  0.1                                    0.3
# 9                                  9.7                                   13.8
#
#    US Crude Rate
# 1           13.2
# 2           12.0
# 4           12.4
# 6            8.9
# 9            6.8

# %%
groups = df.groupby('Sex')

fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group['Population'], group['Deaths'], marker='o', linestyle='', ms=5, label=name)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter(x='Population', y='Deaths', c='Year', colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="930">

# %%
dfA = df.loc[df['Population'] < 4e7]
dfA.head()
# Out:
#    Year     Sex                 Age Race and Hispanic Origin          State  \
# 1  2012    Male         15-24 years       Non-Hispanic White  United States
# 2  2008    Male  Less than 15 years       Non-Hispanic Black  United States
# 4  2010  Female  Less than 15 years       Non-Hispanic White  United States
# 6  2003    Male  Less than 15 years       Non-Hispanic White  United States
# 9  2001    Male         55-64 years       Non-Hispanic Black  United States
#
#    Deaths  Population  Crude Death Rate  Standard Error for Crude Rate  \
# 1    2137    12857283              16.6                            0.4
# 2      15     4687984               0.3                            0.1
# 4      28    16460571               0.2                            0.0
# 6      38    18562010               0.2                            0.0
# 9     129     1100021              11.7                            1.0
#
#    Low Confidence Limit for Crude Rate  Upper Confidence Limit for Crude Rate  \
# 1                                 15.9                                   17.3
# 2                                  0.2                                    0.5
# 4                                  0.1                                    0.2
# 6                                  0.1                                    0.3
# 9                                  9.7                                   13.8
#
#    US Crude Rate
# 1           13.2
# 2           12.0
# 4           12.4
# 6            8.9
# 9            6.8

# %%
groups = dfA.groupby('Sex')

fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group['Population'], group['Deaths'], marker='o', linestyle='', ms=5, label=name)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dfAm = dfA.loc[df['Sex'] == 'Male']
# dfAm.head()
groups = dfAm.groupby('Year')

fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group['Population'], group['Deaths'], marker='o', linestyle='', ms=5, label=name)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dfAm.plot.scatter(x='Population', y='Deaths', c='Year', colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# dfAf = dfA.loc[df['Sex'] == 'Female']
# # dfAf.head()
# groups = dfAf.groupby('Year')

# fig, ax = plt.subplots()
# ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
# for name, group in groups:
#     ax.plot(group['Population'], group['Deaths'], marker='o', linestyle='', ms=5, label=name)
# ax.legend()

# plt.show()

# %%
dfAf.plot.scatter(x='Population', y='Deaths', c='Year', colormap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for el in df['Year'].unique():
    print(el)
# Out:
# 2012
# 2008
# 2010
# 2003
# 2001
# 2002
# 2004
# 2005
# 1999
# 2015
# 2011
# 2014
# 2006
# 2013
# 2000
# 2009
# 2007

# %%
len(df['Year'].unique())
# Out:
# 17

# %%
len(dfA['Year'].unique())
# Out:
# 17

# %%
#use dict to store gender data filtered to be 'male' and 'female' and constrained by year
# MAYBE NOT

# %%
years = sorted(df['Year'].unique())

# %%
genderDict = {}
for year in years:
    tmpDF = df.loc[df['Year'] == year]
    genderDict[year] = tmpDF

# %%
genderDict[1999].head()
# Out:
#      Year     Sex          Age Race and Hispanic Origin          State  \
# 17   1999    Male  55-64 years       Non-Hispanic White  United States
# 22   1999  Female  55-64 years    All Races-All Origins  United States
# 62   1999    Male  35-44 years    All Races-All Origins  United States
# 94   1999    Male  45-54 years    All Races-All Origins  United States
# 223  1999    Male  65-74 years       Non-Hispanic Black  United States
#
#      Deaths  Population  Crude Death Rate  Standard Error for Crude Rate  \
# 17      370     9153776               4.0                            0.2
# 22      431    12378771               3.5                            0.2
# 62     4312    22407074              19.2                            0.3
# 94     2723    17945514              15.2                            0.3
# 223      25      665317               3.8                            0.8
#
#      Low Confidence Limit for Crude Rate  \
# 17                                   3.6
# 22                                   3.2
# 62                                  18.7
# 94                                  14.6
# 223                                  2.4
#
#      Upper Confidence Limit for Crude Rate  US Crude Rate
# 17                                     4.5            6.0
# 22                                     3.8            6.0
# 62                                    19.8            6.0
# 94                                    15.7            6.0
# 223                                    5.5            6.0

# %%
groups = genderDict[1999].groupby('Sex')

fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group['Population'], group['Deaths'], marker='o', linestyle='', ms=5, label=name)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
